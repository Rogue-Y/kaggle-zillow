# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
os.chdir(module_path)

# %%
import config
import train

# %%
config_file = 'test_config'

# Configuration:
config_dict = getattr(config, config_file)

# Mandatory configurations:
# Feature list
feature_list = config_dict['feature_list']
# model
Model = config_dict['model']

# Optional configurations:
# model params:
model_params = config_dict['model_params'] if 'model_params' in config_dict else None
# folds number of K-Fold
FOLDS = config_dict['folds'] if 'folds' in config_dict else 5
# if record training
record = config_dict['record'] if 'record' in config_dict else False
# if generate submission or not
submit = config_dict['submit'] if 'submit' in config_dict else False
# outliers removal upper and lower percentile
outliers_up_pct = config_dict['outliers_up_pct'] if 'outliers_up_pct' in config_dict else 99
outliers_lw_pct = config_dict['outliers_lw_pct'] if 'outliers_lw_pct' in config_dict else 1
# resale offset
resale_offset = config_dict['resale_offset'] if 'resale_offset' in config_dict else 0.012
# clean_na
clean_na = config_dict['clean_na'] if 'clean_na' in config_dict else False
# PCA component
pca_components = config_dict['pca_components'] if 'pca_components' in config_dict else -1
# PCA cannot deal with infinite numbers
if pca_components > 0:
    clean_na = True

prop = train.prepare_features(feature_list)

train_df, transactions = train.prepare_training_data(prop, clean_na)
# Out:
# Feature engineering
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-88b0d3cd309b> in <module>()
#      32     clean_na = True
#      33
# ---> 34 prop = train.prepare_features(feature_list)
#      35
#      36 train_df, transactions = train.prepare_training_data(prop, clean_na)
#
# /home/peter/dev/kaggle-zillow/train.py in prepare_features(feature_list, force_prepare, save_pickle)
#      68         # prop = data_clean.drop_low_ratio_columns(prop)
#      69         prop = data_clean.clean_boolean_data(prop)
# ---> 70         # prop = data_clean.drop_categorical_data(prop)
#      71         prop = data_clean.cat2num(prop)
#      72         if save_pickle:
#
# /home/peter/dev/kaggle-zillow/features/feature_combine.py in feature_combine(df, feature_list, global_force_generate, pickle_folder)
#      46             feature.rename(name, inplace=True)
#      47         features.append(feature)
# ---> 48     return pd.concat([df, *features], axis=1)
#      49
#      50 if __name__ == "__main__":
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     204                        keys=keys, levels=levels, names=names,
#     205                        verify_integrity=verify_integrity,
# --> 206                        copy=copy)
#     207     return op.get_result()
#     208
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     264
#     265             # consolidate
# --> 266             obj._consolidate(inplace=True)
#     267             ndims.add(obj.ndim)
#     268
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _consolidate(self, inplace)
#    3043         inplace = validate_bool_kwarg(inplace, 'inplace')
#    3044         if inplace:
# -> 3045             self._consolidate_inplace()
#    3046         else:
#    3047             f = lambda: self._data.consolidate()
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    3025             self._data = self._data.consolidate()
#    3026
# -> 3027         self._protect_consolidate(f)
#    3028
#    3029     def _consolidate(self, inplace=False):
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    3014         """
#    3015         blocks_before = len(self._data.blocks)
# -> 3016         result = f()
#    3017         if len(self._data.blocks) != blocks_before:
#    3018             self._clear_item_cache()
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in f()
#    3023
#    3024         def f():
# -> 3025             self._data = self._data.consolidate()
#    3026
#    3027         self._protect_consolidate(f)
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in consolidate(self)
#    3571         bm = self.__class__(self.blocks, self.axes)
#    3572         bm._is_consolidated = False
# -> 3573         bm._consolidate_inplace()
#    3574         return bm
#    3575
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    3576     def _consolidate_inplace(self):
#    3577         if not self.is_consolidated():
# -> 3578             self.blocks = tuple(_consolidate(self.blocks))
#    3579             self._is_consolidated = True
#    3580             self._known_consolidated = True
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    4523     for (_can_consolidate, dtype), group_blocks in grouper:
#    4524         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4525                                       _can_consolidate=_can_consolidate)
#    4526         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4527     return new_blocks
#
# /home/peter/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    4546
#    4547         argsort = np.argsort(new_mgr_locs)
# -> 4548         new_values = new_values[argsort]
#    4549         new_mgr_locs = new_mgr_locs[argsort]
#    4550
#
# MemoryError:

# %%
import features.feature_combine

# %%
import features.feature_eng

# %%
feature_combine.list_features(features.feature_eng)

# %%
[t, p] = features.feature_combine.load_train_data()

# %%
df = p.merge(t, how='left', on='parcelid')

# %%
df[df['logerror'].notnull()]
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 362      17073783                    NaN                       NaN
# 428      17088994                    NaN                       NaN
# 470      17100444                    NaN                       NaN
# 480      17102429                    NaN                       NaN
# 507      17109604                    NaN                       NaN
# 555      17125829                    NaN                       NaN
# 570      17132911                    NaN                       NaN
# 580      17134926                    NaN                       NaN
# 605      17139988                    NaN                       NaN
# 719      17167359                    NaN                       NaN
# 757      17179760                    NaN                       NaN
# 805      17198685                    NaN                       NaN
# 853      17212207                    NaN                       NaN
# 858      17213421                    NaN                       NaN
# 1004     17250387                    NaN                       NaN
# 1024     17254534                    NaN                       NaN
# 1041     17260270                    NaN                       NaN
# 1043     17261131                    NaN                       NaN
# 1103     17275640                    NaN                       NaN
# 1105     17275763                    NaN                       NaN
# 1110     17276736                    NaN                       NaN
# 1130     17283162                    NaN                       NaN
# 1132     17283891                    NaN                       NaN
# 1154     17290104                    NaN                       NaN
# 1158     17291231                    NaN                       NaN
# 1179     17296734                    NaN                       NaN
# 1285     10726315                    1.0                       NaN
# 1290     10727091                    NaN                       NaN
# 1309     10730788                    NaN                       NaN
# 1321     10735394                    1.0                       NaN
# ...           ...                    ...                       ...
# 2973191  11348706                    1.0                       NaN
# 2973195  11607868                    1.0                       NaN
# 2973225  10944382                    1.0                       NaN
# 2973282  11793964                    1.0                       NaN
# 2973317  13863024                    NaN                       NaN
# 2973341  14700275                    NaN                       NaN
# 2973342  14700375                    NaN                       NaN
# 2973348  14748051                    NaN                       NaN
# 2973353  17153910                    NaN                       NaN
# 2973404  11485157                    1.0                       NaN
# 2973440  14602791                    NaN                       NaN
# 2973455  13853998                    NaN                       NaN
# 2973474  11780879                    NaN                       NaN
# 2973499  11483546                    1.0                       NaN
# 2973502  11780710                    NaN                       NaN
# 2973509  11125730                    1.0                       NaN
# 2973528  11907577                    1.0                       NaN
# 2973529  12011124                    NaN                       NaN
# 2973531  11812411                    1.0                       NaN
# 2973550  12111197                    1.0                       NaN
# 2973561  11538534                    1.0                       NaN
# 2973567  17095942                    NaN                       NaN
# 2973573  14722093                    NaN                       NaN
# 2973581  14722150                    NaN                       NaN
# 2973643  14600359                    NaN                       NaN
# 2973654  11876798                    1.0                       NaN
# 2973788  12808516                    NaN                       NaN
# 2973814  12010248                    1.0                       NaN
# 2973851  14310905                    NaN                       NaN
# 2973871  14636609                    NaN                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 362               NaN          2.5         3.0                  NaN
# 428               NaN          1.0         2.0                  NaN
# 470               NaN          2.0         3.0                  NaN
# 480               NaN          1.5         2.0                  NaN
# 507               NaN          2.5         4.0                  NaN
# 555               NaN          2.5         4.0                  NaN
# 570               NaN          2.0         3.0                  NaN
# 580               NaN          2.5         5.0                  NaN
# 605               NaN          2.0         3.0                  NaN
# 719               NaN          1.0         3.0                  NaN
# 757               NaN          2.0         4.0                  NaN
# 805               NaN          2.5         4.0                  NaN
# 853               NaN          2.0         5.0                  NaN
# 858               NaN          3.0         3.0                  NaN
# 1004              NaN          2.5         5.0                  NaN
# 1024              NaN          2.0         4.0                  NaN
# 1041              NaN          2.5         5.0                  NaN
# 1043              NaN          1.0         2.0                  NaN
# 1103              NaN          2.5         2.0                  NaN
# 1105              NaN          2.0         2.0                  NaN
# 1110              NaN          1.0         2.0                  NaN
# 1130              NaN          3.0         5.0                  NaN
# 1132              NaN          2.5         4.0                  NaN
# 1154              NaN          2.5         3.0                  NaN
# 1158              NaN          2.0         3.0                  NaN
# 1179              NaN          3.0         5.0                  NaN
# 1285              NaN          3.0         3.0                  NaN
# 1290              NaN          2.0         3.0                  NaN
# 1309              NaN          2.0         4.0                  NaN
# 1321              NaN          3.0         4.0                  NaN
# ...               ...          ...         ...                  ...
# 2973191           NaN          4.0         4.0                  NaN
# 2973195           NaN          3.0         2.0                  NaN
# 2973225           NaN          2.0         1.0                  NaN
# 2973282           NaN          2.0         2.0                  NaN
# 2973317           NaN          3.5         3.0                  NaN
# 2973341           NaN          2.0         3.0                  NaN
# 2973342           NaN          2.0         2.0                  NaN
# 2973348           NaN          2.5         1.0                  NaN
# 2973353           NaN          3.0         4.0                  NaN
# 2973404           NaN          3.0         2.0                  NaN
# 2973440           NaN          1.0         1.0                  NaN
# 2973455           NaN          4.0         5.0                  NaN
# 2973474           NaN          2.0         2.0                  NaN
# 2973499           NaN          2.0         2.0                  NaN
# 2973502           NaN          1.0         1.0                  NaN
# 2973509           NaN          3.0         4.0                  NaN
# 2973528           NaN          3.0         3.0                  NaN
# 2973529           NaN          2.0         0.0                  NaN
# 2973531           NaN          3.0         2.0                  NaN
# 2973550           NaN          1.0         1.0                  NaN
# 2973561           NaN          2.0         2.0                  NaN
# 2973567           NaN          3.0         4.0                  NaN
# 2973573           NaN          2.5         2.0                  NaN
# 2973581           NaN          2.0         2.0                  NaN
# 2973643           NaN          3.0         4.0                  NaN
# 2973654           NaN          3.0         4.0                  NaN
# 2973788           NaN          2.0         3.0                  NaN
# 2973814           NaN          2.0         2.0                  NaN
# 2973851           NaN          2.5         3.0                  NaN
# 2973871           NaN          2.5         3.0                  NaN
#
#          buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 362                        NaN                2.5         NaN
# 428                        NaN                1.0         NaN
# 470                        NaN                2.0         NaN
# 480                        NaN                1.5         NaN
# 507                        NaN                2.5         NaN
# 555                        NaN                2.5        66.0
# 570                        NaN                2.0         NaN
# 580                        NaN                2.5         NaN
# 605                        NaN                2.0         NaN
# 719                        NaN                1.0         NaN
# 757                        NaN                2.0         NaN
# 805                        NaN                2.5         NaN
# 853                        NaN                2.0         NaN
# 858                        NaN                3.0        66.0
# 1004                       NaN                2.5         NaN
# 1024                       NaN                2.0         NaN
# 1041                       NaN                2.5         NaN
# 1043                       NaN                1.0         NaN
# 1103                       NaN                2.5         NaN
# 1105                       NaN                2.0         NaN
# 1110                       NaN                1.0        66.0
# 1130                       NaN                3.0         NaN
# 1132                       NaN                2.5         NaN
# 1154                       NaN                2.5         NaN
# 1158                       NaN                2.0         NaN
# 1179                       NaN                3.0         NaN
# 1285                       4.0                3.0         NaN
# 1290                       7.0                2.0         NaN
# 1309                       7.0                2.0         NaN
# 1321                       4.0                3.0         NaN
# ...                        ...                ...         ...
# 2973191                    1.0                4.0         NaN
# 2973195                   10.0                3.0         NaN
# 2973225                    4.0                2.0         NaN
# 2973282                    1.0                2.0         NaN
# 2973317                    NaN                3.5         NaN
# 2973341                    NaN                2.0         NaN
# 2973342                    NaN                2.0         NaN
# 2973348                    NaN                2.5         NaN
# 2973353                    NaN                3.0         NaN
# 2973404                    1.0                3.0         NaN
# 2973440                    NaN                1.0         NaN
# 2973455                    NaN                4.0         NaN
# 2973474                    4.0                2.0         NaN
# 2973499                    4.0                2.0         NaN
# 2973502                    4.0                1.0         NaN
# 2973509                    4.0                3.0         NaN
# 2973528                    4.0                3.0         NaN
# 2973529                    NaN                2.0         NaN
# 2973531                    4.0                3.0         NaN
# 2973550                    1.0                1.0         NaN
# 2973561                   10.0                2.0         NaN
# 2973567                    NaN                3.0         NaN
# 2973573                    NaN                2.5         NaN
# 2973581                    NaN                2.0         NaN
# 2973643                    NaN                3.0         NaN
# 2973654                    4.0                3.0         NaN
# 2973788                    7.0                2.0         NaN
# 2973814                    4.0                2.0         NaN
# 2973851                    NaN                2.5         NaN
# 2973871                    NaN                2.5         NaN
#
#               ...         structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 362           ...                           115087.0           191811.0
# 428           ...                           143809.0           239679.0
# 470           ...                            33619.0            47853.0
# 480           ...                            45609.0            62914.0
# 507           ...                           277000.0           554000.0
# 555           ...                           222070.0           289609.0
# 570           ...                           185000.0           526000.0
# 580           ...                           342611.0           571086.0
# 605           ...                           231297.0           462594.0
# 719           ...                           134251.0           268502.0
# 757           ...                            42257.0            61453.0
# 805           ...                           239850.0           399742.0
# 853           ...                           230000.0           657000.0
# 858           ...                           142797.0           407991.0
# 1004          ...                           136437.0           201400.0
# 1024          ...                           170705.0           311415.0
# 1041          ...                           225950.0           451900.0
# 1043          ...                            94858.0           158096.0
# 1103          ...                           150363.0           300726.0
# 1105          ...                           126000.0           256000.0
# 1110          ...                           122951.0           204919.0
# 1130          ...                           424187.0           706979.0
# 1132          ...                           265054.0           544564.0
# 1154          ...                           376126.0           626875.0
# 1158          ...                           324000.0           926000.0
# 1179          ...                           397792.0           662986.0
