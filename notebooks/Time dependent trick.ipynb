# %% [markdown]
# # Some brute force to incoorporate time dependence in final submission (6 rows)

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
os.chdir(module_path)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv('data/submissions/Submission_2017-09-10 00:29:15.csv')

# %%
dat.columns
# Out:
# Index(['ParcelId', '201610', '201611', '201612', '201710', '201711', '201712'], dtype='object')

# %%
rate = 0.97
for i in range(6):
    col = dat.columns[i+1]
    dat[col] = dat['201610'] * pow(rate, i)
dat = dat.round(4)

# %%
dat = dat.set_index('ParcelId')

# %%
dat
# Out:
#            201610  201611  201612  201710  201711  201712
# ParcelId
# 10754147  -0.0057 -0.0055 -0.0054 -0.0052 -0.0050 -0.0049
# 10759547  -0.0148 -0.0144 -0.0139 -0.0135 -0.0131 -0.0127
# 10843547   0.0315  0.0306  0.0296  0.0287  0.0279  0.0271
# 10859147   0.0521  0.0505  0.0490  0.0476  0.0461  0.0447
# 10879947   0.0151  0.0146  0.0142  0.0138  0.0134  0.0130
# 10898347   0.0364  0.0353  0.0342  0.0332  0.0322  0.0313
# 10933547   0.0316  0.0307  0.0297  0.0288  0.0280  0.0271
# 10940747   0.0477  0.0463  0.0449  0.0435  0.0422  0.0410
# 10954547  -0.0076 -0.0074 -0.0072 -0.0069 -0.0067 -0.0065
# 10976347   0.0099  0.0096  0.0093  0.0090  0.0088  0.0085
# 11073947   0.0149  0.0145  0.0140  0.0136  0.0132  0.0128
# 11114347  -0.0075 -0.0073 -0.0071 -0.0068 -0.0066 -0.0064
# 11116947  -0.0184 -0.0178 -0.0173 -0.0168 -0.0163 -0.0158
# 11142747  -0.0187 -0.0181 -0.0176 -0.0171 -0.0166 -0.0161
# 11193347  -0.0215 -0.0209 -0.0202 -0.0196 -0.0190 -0.0185
# ...

# %%
dat.to_csv('data/submissions/Submission_0.97.csv')
